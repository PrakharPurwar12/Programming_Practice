# %%
"hii"
# Out:
# 'hii'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# load the dataSet
df = pd.read_csv('Salary_dataset.csv')
df.head()
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0

# %%
# remove unnecessary columns
df=df.iloc[:,1:3]
df.head()
# Out:
#    YearsExperience   Salary
# 0              1.2  39344.0
# 1              1.4  46206.0
# 2              1.6  37732.0
# 3              2.1  43526.0
# 4              2.3  39892.0

# %%
# plot the data
plt.scatter(df['YearsExperience'], df['Salary'], color='red')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.title('Salary vs Years of Experience')
plt.show()

# %%
# Train the model/
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
x = df[['YearsExperience']]#this should be a 2D array
y = df['Salary']# this should be a 1D array
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# making predictions
y_pred = model.predict(x_test)

# %%
# compare the predicted values with the actual values
comparison = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
print(comparison)
# Out:
#       Actual      Predicted
# 2    37732.0   40749.961841
# 28  122392.0  122700.622956
# 13   57082.0   64962.657170
# 10   63219.0   63100.142145
# 26  116970.0  115250.562855
# 24  109432.0  107800.502753

# %%
# evalute the model
from sklearn.metrics import mean_squared_error, r2_score
print('mean square value', mean_squared_error(y_test, y_pred))
print('r^2 score: ', r2_score(y_test, y_pred))
# Out:
# mean square value 12823412.298126565
# r^2 score:  0.988169515729126

# %%
rmse  = np.sqrt(mean_squared_error(y_test, y_pred))
rmse
# Out:
# np.float64(3580.9792373213454)

# %%
# plot the regression line
plt.scatter(x_test, y_test, color='red')
plt.plot(x_test, y_pred, color='blue', linewidth=2)
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.title('Salary vs Years of Experience (Regression Line)')
plt.show()
