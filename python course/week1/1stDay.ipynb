# %%
print("hello world")
# Out:
# hello world

# %%
for i in range(5):
    print(i, end=" ")
# Out:
# 0 1 2 3 4

# %%
n =10
for i in range(n):
    print("*"*n)
# Out:
# **********
# **********
# **********
# **********
# **********
# **********
# **********
# **********
# **********
# **********

# %%
n =10
for i in range(n):
    print("*"*(i+1))
# Out:
# *
# **
# ***
# ****
# *****
# ******
# *******
# ********
# *********
# **********

# %%
n =10
for i in range(n):
    print("*"*(n-i))
# Out:
# **********
# *********
# ********
# *******
# ******
# *****
# ****
# ***
# **
# *

# %%
n =10
for i in range(n):
    print(" "*i, end="")
    print("*"*(n-i))
# Out:
# **********
#  *********
#   ********
#    *******
#     ******
#      *****
#       ****
#        ***
#         **
#          *

# %%
n =10
for i in range(n):
    print(" "*(n-i), end="")
    print("*"*(i+1))
# Out:
#           *
#          **
#         ***
#        ****
#       *****
#      ******
#     *******
#    ********
#   *********
#  **********

# %%
for i in range(n + 1):
        if i < n:
            spaces = ' ' * (n - i - 1)
            stars = '*' * (2 * i + 1)
            print(spaces + stars)
        else:
            trunk_spaces = ' ' * (n - 1)
# Out:
#          *
#         ***
#        *****
#       *******
#      *********
#     ***********
#    *************
#   ***************
#  *****************
# *******************
