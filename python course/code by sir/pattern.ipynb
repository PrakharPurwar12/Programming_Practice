# %%
print("hello world")

# %%
for i in range(10):
    print(i)

# %%
for i in range(10):
    print(i, end = " ")

# %%
n = 10
for i in range(10):
    print("*")

# %%
n = 10
for i in range(10):
    print("*", end = " ")

# %%
n = 10
for i in range(10):
    print("*" * n)

# %%
n = 10
for i in range(10):
    print("*" * (i+1))

# %%
n = 10
for i in range(10):
    print("*" * (n-i))

# %%
n = 10
for i in range(10):
    print(' '*i, end= "" )
    print("*"* (n-i))

# %%
n = 10
for i in range(10):
    print(' '*(n-i), end= "" )
    print("*"* (i+1))

# %%
n= 10
for i in range(10):
    stars = 2*i+1
    spaces= n-i-1
    print(" "*spaces + "*" * stars)
