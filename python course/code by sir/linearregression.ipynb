# %% [markdown]
# ### import necessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### load the dataset

# %%
df = pd.read_csv("Salary_dataset.csv")

# %%
df.head(10)
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0
# 5           5              3.0  56643.0
# 6           6              3.1  60151.0
# 7           7              3.3  54446.0
# 8           8              3.3  64446.0
# 9           9              3.8  57190.0

# %% [markdown]
# ### remove unwanted column

# %%
df = df.iloc[:, 1:]

# %%
df.head(10)
# Out:
#    YearsExperience   Salary
# 0              1.2  39344.0
# 1              1.4  46206.0
# 2              1.6  37732.0
# 3              2.1  43526.0
# 4              2.3  39892.0
# 5              3.0  56643.0
# 6              3.1  60151.0
# 7              3.3  54446.0
# 8              3.3  64446.0
# 9              3.8  57190.0

# %% [markdown]
# ### plot the data

# %%
plt.scatter(df['YearsExperience'], df['Salary'], color = 'blue')
plt.xlabel("Years of Experience ")
plt.ylabel("Salary")
plt.title("Salary vs Experience")
plt.show()

# %% [markdown]
# ### Train the model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
X = df[['YearsExperience']] # this should be in 2D
y= df['Salary']  # 1D
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### making predictions

# %%
y_pred = model.predict(X_test)

# %%
comparison = pd.DataFrame({'Actual: ': y_test, 'Predicted: ' : y_pred})

# %%
print(comparison )
# Out:
#     Actual:     Predicted:
# 2    37732.0   40749.961841
# 28  122392.0  122700.622956
# 13   57082.0   64962.657170
# 10   63219.0   63100.142145
# 26  116970.0  115250.562855
# 24  109432.0  107800.502753

# %% [markdown]
# ### evaluate the model:

# %%
from sklearn.metrics import mean_squared_error, r2_score
print("mean sqaure value: ", mean_squared_error(y_test, y_pred))
print("R^2 Score: ", r2_score(y_test, y_pred))
# Out:
# mean sqaure value:  12823412.298126565
# R^2 Score:  0.988169515729126

# %%
rmse = np.sqrt(12823412.298)

# %%
rmse
# Out:
# 3580.9792373036735

# %% [markdown]
# ### plot the regression line

# %%
plt.scatter(X_test, y_test, color= 'blue')
plt.plot(X_test, y_pred, color= 'red', linewidth = 2)
plt.title("Regression line on test data")
plt.xlabel("Years of exp")
plt.ylabel("Salary")
plt.show()
